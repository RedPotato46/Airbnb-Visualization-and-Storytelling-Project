# %% [markdown]
# ## AirBnB Assignment Part II Stub File

# %% [markdown]
# #### Guidelines
#
# - Go through the data dictionary thoroughly before starting the assignment. That will give you a good idea of what each column represents before you begin the analysis.
#
#
# - Read each instruction carefully, identify the task to be performed, and only then write the required code. The assignment is meant to be straightforward. You do not need to perform additional analyses that are not requested explicitly. However you are encouraged to perform a few additional analyses to get deeper into the insights
#
#
# - Some of the tasks might require using functions you may not have used previously. In such cases, you should rely on the library documentation you referred to in the modules. Please understand that completing this assignment is a learning process, and research is part of it.
#
#
# - Always run the cells of the Notebook sequentially, restart the kernel, and run all the cells to avoid runtime errors.
#
#
# - For each of the tasks, there's a code cell where you are supposed to write the code and a markdown cell below it mentioning to either write the answer or mention your observations/insights from the output of the code.
#
#
# - Many of the questions will require you to view them from multiple angles. You have been asked to **observe any trends in the visualizations and provide insights for these trends**. In other words, there will be no fixed answers. You are expected to apply your problem-solving skills to come up with solutions and also document your work appropriately; both of these are part of the assignment grading.

# %%
##Import the libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt

# %%
#Load the dataset
df = pd.read_csv('airbnblistings.csv')
df
# Out:
#                       id                                               name  \
# 0                   2818           Quiet Garden View Room & Super Fast WiFi
# 1                  20168       Studio with private bathroom in the centre 1
# 2                  27886  Romantic, stylish B&B houseboat in canal district
# 3                  28871                            Comfortable double room
# 4                  29051                            Comfortable single room
# ...                  ...                                                ...
# 6168  640454062441222339                                       Villa Newbia
# 6169  640513271677293480  Central | Clean | Cozy APT & Roof Terrace @ De...
# 6170  640524575959045684   Central | Bright | Clean Studio w WiFi @ De Pijp
# 6171  641058574307869532                     City centrum private studio 14
# 6172  641131762118036107               Lovely one bedroom in Amsterdam Zuid
#
#         host_id  host_name  host_since_Year  \
# 0          3159     Daniel             2008
# 1         59484  Alexander             2009
# 2         97647       Flip             2010
# 3        124245      Edwin             2010
# 4        124245      Edwin             2010
# ...         ...        ...              ...
# 6168  462196214   Jennifer             2022
# 6169   49154714     Reiner             2015
# 6170   49154714     Reiner             2015
# 6171  449825081      Dario             2022
# 6172    9435259    Thierry             2013
#
#                                neighbourhood   latitude  longitude  \
# 0     Oostelijk Havengebied - Indische Buurt  52.364350   4.943580
# 1                               Centrum-Oost  52.364070   4.893930
# 2                               Centrum-West  52.387610   4.891880
# 3                               Centrum-West  52.367750   4.890920
# 4                               Centrum-Oost  52.365840   4.891110
# ...                                      ...        ...        ...
# 6168                            Centrum-Oost  52.368625   4.908474
# 6169                 De Pijp - Rivierenbuurt  52.357466   4.897642
# 6170                 De Pijp - Rivierenbuurt  52.354610   4.888740
# 6171                            Centrum-West  52.376636   4.895509
# 6172                                    Zuid  52.343521   4.861253
#
#             room_type  price  ...  last_review  review_scores_rating  \
# 0        Private room     49  ...   2022-06-01                  4.89
# 1        Private room    106  ...   2020-04-09                  4.44
# 2        Private room    126  ...   2022-04-24                  4.94
# 3        Private room     75  ...   2022-06-04                  4.88
# 4        Private room     55  ...   2022-06-02                  4.79
# ...               ...    ...  ...          ...                   ...
# 6168  Entire home/apt    610  ...          NaN                   NaN
# 6169  Entire home/apt    109  ...          NaN                   NaN
# 6170  Entire home/apt    109  ...          NaN                   NaN
# 6171  Entire home/apt     94  ...          NaN                   NaN
# 6172     Private room     85  ...          NaN                   NaN
#
#      review_scores_accuracy  review_scores_cleanliness  review_scores_checkin  \
# 0                      4.93                       5.00                   4.97
# 1                      4.69                       4.79                   4.63
# 2                      4.92                       4.95                   4.95
# 3                      4.95                       4.90                   4.96
# 4                      4.88                       4.84                   4.92
# ...                     ...                        ...                    ...
# 6168                    NaN                        NaN                    NaN
# 6169                    NaN                        NaN                    NaN
# 6170                    NaN                        NaN                    NaN
# 6171                    NaN                        NaN                    NaN
# 6172                    NaN                        NaN                    NaN
#
#       review_scores_communication  review_scores_location  \
# 0                            4.98                    4.69
# 1                            4.62                    4.87
# 2                            4.92                    4.89
# 3                            4.94                    4.97
# 4                            4.91                    4.87
# ...                           ...                     ...
# 6168                          NaN                     NaN
# 6169                          NaN                     NaN
# 6170                          NaN                     NaN
# 6171                          NaN                     NaN
# 6172                          NaN                     NaN
#
#       review_scores_value  accommodates  bedrooms
# 0                    4.82             2       1.0
# 1                    4.49             2       1.0
# 2                    4.79             2       1.0
# 3                    4.83             2       1.0
# 4                    4.76             1       1.0
# ...                   ...           ...       ...
# 6168                  NaN            12       6.0
# 6169                  NaN             2       1.0
# 6170                  NaN             2       1.0
# 6171                  NaN             2       NaN
# 6172                  NaN             1       1.0
#
# [6173 rows x 22 columns]

# %%
#check the top 5 rows
df1=df.head()
df1
# Out:
#       id                                               name  host_id  \
# 0   2818           Quiet Garden View Room & Super Fast WiFi     3159
# 1  20168       Studio with private bathroom in the centre 1    59484
# 2  27886  Romantic, stylish B&B houseboat in canal district    97647
# 3  28871                            Comfortable double room   124245
# 4  29051                            Comfortable single room   124245
#
#    host_name  host_since_Year                           neighbourhood  \
# 0     Daniel             2008  Oostelijk Havengebied - Indische Buurt
# 1  Alexander             2009                            Centrum-Oost
# 2       Flip             2010                            Centrum-West
# 3      Edwin             2010                            Centrum-West
# 4      Edwin             2010                            Centrum-Oost
#
#    latitude  longitude     room_type  price  ...  last_review  \
# 0  52.36435    4.94358  Private room     49  ...   2022-06-01
# 1  52.36407    4.89393  Private room    106  ...   2020-04-09
# 2  52.38761    4.89188  Private room    126  ...   2022-04-24
# 3  52.36775    4.89092  Private room     75  ...   2022-06-04
# 4  52.36584    4.89111  Private room     55  ...   2022-06-02
#
#    review_scores_rating review_scores_accuracy  review_scores_cleanliness  \
# 0                  4.89                   4.93                       5.00
# 1                  4.44                   4.69                       4.79
# 2                  4.94                   4.92                       4.95
# 3                  4.88                   4.95                       4.90
# 4                  4.79                   4.88                       4.84
#
#    review_scores_checkin  review_scores_communication  review_scores_location  \
# 0                   4.97                         4.98                    4.69
# 1                   4.63                         4.62                    4.87
# 2                   4.95                         4.92                    4.89
# 3                   4.96                         4.94                    4.97
# 4                   4.92                         4.91                    4.87
#
#    review_scores_value  accommodates  bedrooms
# 0                 4.82             2       1.0
# 1                 4.49             2       1.0
# 2                 4.79             2       1.0
# 3                 4.83             2       1.0
# 4                 4.76             1       1.0
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Task 1
# Basic Descriptive Statistics
# - 1.1 How many AirBnB listings are there in the city of Amsterdam?

# %%
Amsterdam_total_listings=df['id'].count()
print(f'The total no of Airbnb listings in the city of Amsterdam are {Amsterdam_total_listings}.')
# Out:
# The total no of Airbnb listings in the city of Amsterdam are 6173.

# %% [markdown]
# **Answer**:

# %% [markdown]
# - 1.2 What is the average price of all the AirBnB listings in Amsterdam?

# %%
average_price=df['price'].mean()
print(f'The average price of all the AirBnB listings in Amsterdam is {average_price}.')
# Out:
# The average price of all the AirBnB listings in Amsterdam is 198.01960149036125.

# %% [markdown]
# **Answer**:

# %% [markdown]
# - 1.3 - What is the average rating received by all the AirBnB listings in Amsterdam? *Hint* - Use the `review_scores_rating` column for answering this question

# %%
average_rating_received=df['review_scores_rating'].mean()
print(f'the average rating received by all the AirBnB listings in Amsterdam is {average_rating_received}.')
# Out:
# the average rating received by all the AirBnB listings in Amsterdam is 4.800856170517643.

# %% [markdown]
# **Answer**:

# %% [markdown]
# ### Task 2
#
# Plot a histogram for the following variables and observe their distribution. Choose the parameters like bin width, number of bins, etc. as per your choice.
#
# - `price`
# - `number_of_reviews`
# - `review_scores_rating`

# %%
##For Price
bin_start=0
bin_end=3000
bin_width=250
price_histogram=sns.histplot(df["price"],bins=range(bin_start,bin_end,bin_width))
# Out:
# C:\Users\ADMIN\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# **Observation**:

# %%
##For no of reviews
bin_start=0
bin_end=1500
bin_width=200
no_of_reviews_histogram=sns.histplot(df["number_of_reviews"],bins=range(bin_start,bin_end,bin_width))
# Out:
# C:\Users\ADMIN\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# **Observation**:

# %%
##For distribution of ratings
bin_start=0
bin_end=6
ratings_histogram=sns.histplot(df["review_scores_rating"],bins=range(bin_start,bin_end))
# Out:
# C:\Users\ADMIN\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# **Observation**:

# %% [markdown]
# ### Task 3
#
# Plot a visualization to show the number of listings for each `room_type`
#
# Which `room_type` has the highest number of listings?

# %%
##First,plotting a histogram to show the number of listings for each room_type
room_type=sns.histplot(df["room_type"])
print(f'The highest no of listings is for Entire home/apt room type')
# Out:
# The highest no of listings is for Entire home/apt room type
# C:\Users\ADMIN\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# **Observation** -

# %% [markdown]
# ### Task 4
#
# You want to observe the relationship between the reviews(given by `number_of_reviews`) and the ratings received (`review_scores_rating`) by different AirBnB listings.
#
# For this, plot both a scatterplot and a jointplot. What can you say about the relationship between ratings and reviews?

# %%
##Write your code here for scatterplot
relation1=sns.scatterplot(data=df,x= "review_scores_rating",y="number_of_reviews",color="green")
print(f'As we see in this scatterplot the no of reviews for score ratings for 1,2,3 is 0,but it gradually starts increasing from rating 3')
# Out:
# As we see in this scatterplot the no of reviews for score ratings for 1,2,3 is 0,but it gradually starts increasing from rating 3

# %%
##Write your code here for jointplot
relation2=sns.jointplot(data=df,x= "review_scores_rating",y="number_of_reviews",color="green")
# Out:
# C:\Users\ADMIN\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ADMIN\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# **Observation** -

# %% [markdown]
# ### Task 5
#
# AirBnB has been adding quite a few listings in the city of Amseterdam since they started operating in 2008. Plot a lineplot to observe how the average `review_scores_rating` has changed across the different years (use `host_since_Year` column) AirBnB has been operating in the city.

# %%
### Write your code for lineplot here
year_ratings=sns.lineplot(data=df,x="host_since_Year",y="review_scores_rating",color="green")
# Out:
# C:\Users\ADMIN\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ADMIN\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
##As we can see the rating in the following chart has been suddenly decreased in the year 2008;
##After 2008 there has been a slight increase in the year 2010.
##Between 2010 & 2016 the rating varies between 4.8 & 4.9.
##But after that it can be seen decreasing till the year 2022 which lies between 4.6 & 4.7.

# %% [markdown]
# **Observation** -

# %% [markdown]
# ### Task 6
#
# You wish to identify the relationship between the various ratings each of the listing has received from the customers.
# These ratings have been summarized below:

# %%
review_columns = df[['review_scores_rating',
 'review_scores_accuracy',
 'review_scores_cleanliness',
 'review_scores_checkin',
 'review_scores_communication',
 'review_scores_location',
 'review_scores_value']]
review_columns.head()
# Out:
#    review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 0                  4.89                    4.93                       5.00
# 1                  4.44                    4.69                       4.79
# 2                  4.94                    4.92                       4.95
# 3                  4.88                    4.95                       4.90
# 4                  4.79                    4.88                       4.84
#
#    review_scores_checkin  review_scores_communication  review_scores_location  \
# 0                   4.97                         4.98                    4.69
# 1                   4.63                         4.62                    4.87
# 2                   4.95                         4.92                    4.89
# 3                   4.96                         4.94                    4.97
# 4                   4.92                         4.91                    4.87
#
#    review_scores_value
# 0                 4.82
# 1                 4.49
# 2                 4.79
# 3                 4.83
# 4                 4.76

# %% [markdown]
# Plot a heatmap of the correlation matrix of the above ratings variables and document your observations. You can use this link to understand these variables further - https://www.airbnb.co.in/help/article/1257/star-ratings

# %%
corr=review_columns.corr()
corr
sns.heatmap(data=corr,cmap="mako",center=0)
# Out:
# <Axes: >

# %% [markdown]
# **Observation** -

# %% [markdown]
# ### Task 7

# %% [markdown]
# Analyze the listings' prices across the following neighborhoods using a categorical boxplot
# - 'Westerpark', 'Oud-Noord', 'Noord-West','Zuid'

# %%
nc = ['Westerpark', 'Oud-Noord', 'Noord-West','Zuid']

# %%
### Write your code for subsetting the data for only the above neighborhoods here
nc = ['Westerpark', 'Oud-Noord', 'Noord-West','Zuid']
subset_df=df[df['neighbourhood'].isin(nc)]
subset_df
# Out:
#                       id                                              name  \
# 9                  55868               Apartment near Museumplein (centre)
# 15                 97476        Spacious, bright apartment near Vondelpark
# 33                262394                 Charming Studio with Roof Terrace
# 35                283170                5-bedrooms house; central location
# 59                414865                  Charming house, perfect for two!
# ...                  ...                                               ...
# 6161  638924385323624315   Lovely studio room next to beautiful Westerpark
# 6162  638943111845174427                Lovely 1-bedroom loft in Amsterdam
# 6163  639087957745163371         Lovely 2-bedroom condo in Amsterdam South
# 6164  639667369450249097  1x Bedroom, 20m2 Terrace, BBQ, 2 floors on 120m2
# 6172  641131762118036107              Lovely one bedroom in Amsterdam Zuid
#
#         host_id host_name  host_since_Year neighbourhood   latitude  \
# 9        264178  Cornelie             2010          Zuid  52.355970
# 15       485930    Rachel             2011          Zuid  52.356650
# 33      1376607    Martin             2011          Zuid  52.356950
# 35      1451657     Marco             2011          Zuid  52.354350
# 59      2063261   Miranda             2012          Zuid  52.350430
# ...         ...       ...              ...           ...        ...
# 6161    9550824    Ashley             2013    Westerpark  52.383684
# 6162   72656897     Paula             2016    Westerpark  52.389883
# 6163  291545715    Edvina             2019          Zuid  52.343134
# 6164    1177084    Philip             2011          Zuid  52.350461
# 6172    9435259   Thierry             2013          Zuid  52.343521
#
#       longitude        room_type  price  ...  last_review  \
# 9      4.885120  Entire home/apt    149  ...   2020-01-03
# 15     4.863630  Entire home/apt    115  ...   2022-03-27
# 33     4.852340     Private room     88  ...   2019-10-07
# 35     4.873160  Entire home/apt   1036  ...   2022-05-15
# 59     4.846760  Entire home/apt    110  ...   2022-05-15
# ...         ...              ...    ...  ...          ...
# 6161   4.872321     Private room    112  ...          NaN
# 6162   4.874386  Entire home/apt    129  ...          NaN
# 6163   4.862145  Entire home/apt    280  ...          NaN
# 6164   4.858218     Private room    100  ...          NaN
# 6172   4.861253     Private room     85  ...          NaN
#
#       review_scores_rating review_scores_accuracy  review_scores_cleanliness  \
# 9                     4.86                   4.91                       4.86
# 15                    4.89                   4.96                       4.91
# 33                    4.83                   4.83                       4.86
# 35                    4.52                   4.55                       4.56
# 59                    4.88                   4.88                       4.63
# ...                    ...                    ...                        ...
# 6161                   NaN                    NaN                        NaN
# 6162                   NaN                    NaN                        NaN
# 6163                   NaN                    NaN                        NaN
# 6164                   NaN                    NaN                        NaN
# 6172                   NaN                    NaN                        NaN
#
#       review_scores_checkin  review_scores_communication  \
# 9                      4.95                         4.98
# 15                     4.94                         4.96
# 33                     4.98                         4.95
# 35                     4.71                         4.83
# 59                     4.88                         5.00
# ...                     ...                          ...
# 6161                    NaN                          NaN
# 6162                    NaN                          NaN
# 6163                    NaN                          NaN
# 6164                    NaN                          NaN
# 6172                    NaN                          NaN
#
#       review_scores_location  review_scores_value  accommodates  bedrooms
# 9                       4.95                 4.80             4       2.0
# 15                      4.85                 4.85             2       1.0
# 33                      4.69                 4.66             2       1.0
# 35                      4.71                 4.14            12       5.0
# 59                      4.75                 4.75             2       1.0
# ...                      ...                  ...           ...       ...
# 6161                     NaN                  NaN             2       1.0
# 6162                     NaN                  NaN             2       1.0
# 6163                     NaN                  NaN             4       2.0
# 6164                     NaN                  NaN             2       1.0
# 6172                     NaN                  NaN             1       1.0
#
# [1216 rows x 22 columns]

# %%
### Write your code for plotting the categorical boxplot here
##Sorry,Not able to perform.

# %% [markdown]
# **Observation** -

# %% [markdown]
# The total no of Airbnb listings in the city of Amsterdam are 6173.
# The average price of all the AirBnB listings in Amsterdam is 198.
# The average rating received by all the AirBnB listings in Amsterdam is 4.8.
# Comparing the distribution of prices,reviews and ratings we have observed that the highest count of no of prices lies between 0 to 500,no 5 is highest among all the scores rating & the highest no of reviews lies between 0 to 200,followed by slightly lesser than 200 to 400 reviews.
# Entire home/apt room type has the highest no of listings.
# As we see in this scatterplot the no of reviews for score ratings for 1,2,3 is 0,but it gradually starts increasing from rating 3.
# We can also see the rating in the following chart has been suddenly decreased in the year 2008;
# After 2008 there has been a slight increase in the year 2010.
# Between 2010 & 2016 the rating varies between 4.8 & 4.9.
# But after that it can be seen decreasing till the year 2022 which lies between 4.6 & 4.7.
# The relation between the various ratings which were provided is also shown with the help of correlation matrix and heat map.
# Subset of the given neighbourhoods - 'Westerpark', 'Oud-Noord', 'Noord-West','Zuid' has also been created.
